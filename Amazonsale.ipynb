# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\sayali\Documents\Amazon_sales_report2.csv')
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128971  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128972  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128973  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128974  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128975  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  Qty  \
# 128971     Amazon.in          Expedited    Shirt   XL        Shipped    1
# 128972     Amazon.in          Expedited  T-shirt    M        Shipped    1
# 128973     Amazon.in          Expedited  Blazzer  XXL        Shipped    1
# 128974     Amazon.in          Expedited  T-shirt   XS        Shipped    1
# 128975     Amazon.in          Expedited  T-shirt    S        Shipped    1
#
#        currency  Amount  ship-city    ship-state  ship-postal-code  \
# ...

# %%
pd.isnull(df)
# Out:
#         index  Order ID   Date  Status  Fulfilment  Sales Channel  \
# 0       False     False  False   False       False          False
# 1       False     False  False   False       False          False
# 2       False     False  False   False       False          False
# 3       False     False  False   False       False          False
# 4       False     False  False   False       False          False
# ...       ...       ...    ...     ...         ...            ...
# 128971  False     False  False   False       False          False
# 128972  False     False  False   False       False          False
# 128973  False     False  False   False       False          False
# 128974  False     False  False   False       False          False
# 128975  False     False  False   False       False          False
#
#         ship-service-level  Category   Size  Courier Status    Qty  currency  \
# 0                    False     False  False           False  False     False
# ...

# %%
pd.isnull(df).sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               7800
# Amount                 7800
# ship-city                35
# ship-state               35
# ship-postal-code         35
# ship-country             35
# B2B                       0
# fulfilled-by          89713
# dtype: int64

# %%
df.shape
# Out:
# (128976, 19)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (37514, 19)

# %%
pd.isnull(df).sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37514 entries, 0 to 128892
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               37514 non-null  int64
#  1   Order ID            37514 non-null  object
#  2   Date                37514 non-null  object
#  3   Status              37514 non-null  object
#  4   Fulfilment          37514 non-null  object
#  5   Sales Channel       37514 non-null  object
#  6   ship-service-level  37514 non-null  object
#  7   Category            37514 non-null  object
#  8   Size                37514 non-null  object
#  9   Courier Status      37514 non-null  object
#  10  Qty                 37514 non-null  int64
#  11  currency            37514 non-null  object
#  12  Amount              37514 non-null  float64
#  13  ship-city           37514 non-null  object
#  14  ship-state          37514 non-null  object
# ...

# %%
df.head()
# Out:
#     index             Order ID      Date                        Status  \
# 0       0  405-8078784-5731545  04-30-22                     Cancelled
# 1       1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 3       3  403-9615377-8133951  04-30-22                     Cancelled
# 7       7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 12     12  405-5513694-8146768  04-30-22  Shipped - Delivered to Buyer
#
#    Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0    Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1    Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
# 3    Merchant     Amazon.in           Standard  Blazzer    L     On the Way
# 7    Merchant     Amazon.in           Standard    Shirt    S        Shipped
# 12   Merchant     Amazon.in           Standard    Shirt   XS        Shipped
#
#     Qty currency  Amount   ship-city   ship-state  ship-postal-code  \
# ...

# %%
df['ship-postal-code'] = df['ship-postal-code'].astype('int')

# %%
df['ship-postal-code'].dtype
# Out:
# dtype('int32')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.describe()
# Out:
#                index                           Date           Qty  \
# count   37514.000000                          37514  37514.000000
# mean    60953.809858  2022-05-11 07:56:47.303939840      0.867383
# min         0.000000            2022-03-31 00:00:00      0.000000
# 25%     27235.250000            2022-04-20 00:00:00      1.000000
# 50%     63470.500000            2022-05-09 00:00:00      1.000000
# 75%     91790.750000            2022-06-01 00:00:00      1.000000
# max    128891.000000            2022-06-29 00:00:00      5.000000
# std     36844.853039                            NaN      0.354160
#
#              Amount  ship-postal-code
# count  37514.000000      37514.000000
# mean     646.553960     463291.552754
# min        0.000000     110001.000000
# 25%      458.000000     370465.000000
# 50%      629.000000     500019.000000
# 75%      771.000000     600042.000000
# max     5495.000000     989898.000000
# std      279.952414     194550.425637

# %%
df.describe(include='object')
# Out:
#                    Order ID                        Status Fulfilment  \
# count                 37514                         37514      37514
# unique                34664                            11          1
# top     171-5057375-2831560  Shipped - Delivered to Buyer   Merchant
# freq                     12                         28741      37514
#
#        Sales Channel ship-service-level Category   Size Courier Status  \
# count          37514              37514    37514  37514          37514
# unique             1                  1        8     11              3
# top        Amazon.in           Standard  T-shirt      M        Shipped
# freq           37514              37514    14062   6806          31859
#
#        currency  ship-city   ship-state ship-country fulfilled-by
# count     37514      37514        37514        37514        37514
# unique        1       4698           58            1            1
# ...

# %%
df[['Qty','Amount']].describe()
# Out:
#                 Qty        Amount
# count  37514.000000  37514.000000
# mean       0.867383    646.553960
# std        0.354160    279.952414
# min        0.000000      0.000000
# 25%        1.000000    458.000000
# 50%        1.000000    629.000000
# 75%        1.000000    771.000000
# max        5.000000   5495.000000

# %%
df.head()
# Out:
#     index             Order ID       Date                        Status  \
# 0       0  405-8078784-5731545 2022-04-30                     Cancelled
# 1       1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 3       3  403-9615377-8133951 2022-04-30                     Cancelled
# 7       7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 12     12  405-5513694-8146768 2022-04-30  Shipped - Delivered to Buyer
#
#    Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0    Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1    Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
# 3    Merchant     Amazon.in           Standard  Blazzer    L     On the Way
# 7    Merchant     Amazon.in           Standard    Shirt    S        Shipped
# 12   Merchant     Amazon.in           Standard    Shirt   XS        Shipped
#
#     Qty currency  Amount   ship-city   ship-state  ship-postal-code  \
# ...

# %%
ax=sns.countplot(x='Size',data=df,hue=None,palette='viridis')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Count of Products By Sizes')
# Out:
# C:\Users\sayali\AppData\Local\Temp\ipykernel_9180\1624664944.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='Size',data=df,hue=None,palette='viridis')
# Text(0.5, 1.0, 'Count of Products By Sizes')

# %% [markdown]
# # most of the people buys M-size

# %%
import matplotlib.pyplot as plt
import seaborn as sns

selected_courier_statuses = ['Cancelled', 'Shipped', 'Pending']

filtered_df = df[df['Courier Status'].isin(selected_courier_statuses)]

plt.figure(figsize=(10,6))
sns.countplot(data=filtered_df, x='Courier Status', hue='Status')
plt.title('Shipping Status (Cancelled, Shipped, Pending)')
plt.show()

# %% [markdown]
# # Majority to the orders are Shipped through the courier

# %%
df.head()
# Out:
#     index             Order ID       Date                        Status  \
# 0       0  405-8078784-5731545 2022-04-30                     Cancelled
# 1       1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 3       3  403-9615377-8133951 2022-04-30                     Cancelled
# 7       7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 12     12  405-5513694-8146768 2022-04-30  Shipped - Delivered to Buyer
#
#    Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0    Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1    Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
# 3    Merchant     Amazon.in           Standard  Blazzer    L     On the Way
# 7    Merchant     Amazon.in           Standard    Shirt    S        Shipped
# 12   Merchant     Amazon.in           Standard    Shirt   XS        Shipped
#
#     Qty currency  Amount   ship-city   ship-state  ship-postal-code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37514 entries, 0 to 128892
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               37514 non-null  int64
#  1   Order ID            37514 non-null  object
#  2   Date                37514 non-null  datetime64[ns]
#  3   Status              37514 non-null  object
#  4   Fulfilment          37514 non-null  object
#  5   Sales Channel       37514 non-null  object
#  6   ship-service-level  37514 non-null  object
#  7   Category            37514 non-null  object
#  8   Size                37514 non-null  object
#  9   Courier Status      37514 non-null  object
#  10  Qty                 37514 non-null  int64
#  11  currency            37514 non-null  object
#  12  Amount              37514 non-null  float64
#  13  ship-city           37514 non-null  object
#  14  ship-state          37514 non-null  object
# ...

# %%
df['Category'] = df['Category'].astype(str)
c_d=df['Category']
plt.figure(figsize=(10,6))
plt.hist(c_d,bins=30,edgecolor='black',color='olive')
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('count')
plt.title('product sale by category')
plt.show()

# %% [markdown]
# # Most of the Buyer are T-shirt purchaser

# %%
check_B2B=df['B2B'].value_counts()

plt.pie(check_B2B,labels=check_B2B.index,autopct='%1.1f%%',colors=['powderblue', 'teal'])
plt.title('Buyer Category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Maximum 99.2% of buyers are Retailer and 0.8% are wholeseller

# %%
import numpy as np

fulfillment_counts = df['Fulfilment'].value_counts()


plt.figure(figsize=(6,6))
plt.pie(fulfillment_counts, labels=fulfillment_counts.index, autopct='%1.1f%%', colors=['navy', 'lightsteelblue'], wedgeprops=dict(width=0.4))
plt.title("Orders Fulfilled by Merchant vs Amazon")
plt.show()

# %% [markdown]
# # Maximum 69.6% of order Fullfilled by AMAZON and remaining 30.4% fullfilled by MERCHANT

# %%
x_data = df['Category']
y_data = df['Size']


plt.scatter(x_data,y_data)
plt.xlabel('Category')
plt.ylabel('Size')
plt.title('Available Size')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df['Date'] = pd.to_datetime(df['Date'], errors='coerce')



monthly_avg = df.groupby(df['Date'].dt.to_period("M"))['Amount'].mean()


plt.figure(figsize=(8,5))
plt.plot(monthly_avg.index.astype(str), monthly_avg.values, marker='o', linestyle='-', color='teal')


plt.xlabel("Month")
plt.ylabel("Average Order Amount (INR)")
plt.title("Average Monthly Order Amount")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
top10_state = df['ship-state'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.countplot(data=df[df['ship-state'].isin(top10_state.index)], 
              x='ship-state', 
              order=top10_state.index,  # Ensure correct order
              palette=sns.color_palette("tab10", 10))  # Use 10 distinct colors

plt.xlabel('State')
plt.ylabel('Orders Count')
plt.title('Distribution Across State')
plt.xticks(rotation=90)

plt.show()
# Out:
# C:\Users\sayali\AppData\Local\Temp\ipykernel_13540\2148285324.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df[df['ship-state'].isin(top10_state.index)],

# %% [markdown]
# # Most of Buyers Are From Maharashtra State

# %%
import matplotlib.pyplot as plt
import seaborn as sns



ax=sns.countplot(x='Size',data=df,hue=None,palette='viridis')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Count of Products By Sizes')
import matplotlib.pyplot as plt
import seaborn as sns

selected_courier_statuses = ['Cancelled', 'Shipped', 'Pending']

filtered_df = df[df['Courier Status'].isin(selected_courier_statuses)]

plt.figure(figsize=(10,6))
sns.countplot(data=filtered_df, x='Courier Status', hue='Status')
plt.title('Shipping Status (Cancelled, Shipped, Pending)')
plt.show()

df['Category'] = df['Category'].astype(str)
c_d=df['Category']
plt.figure(figsize=(10,6))
plt.hist(c_d,bins=30,edgecolor='black',color='teal')
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('count')
plt.title('product sale by category')
plt.show()
check_B2B=df['B2B'].value_counts()

plt.pie(check_B2B,labels=check_B2B.index,autopct='%1.1f%%',colors=['powderblue', 'teal'])
plt.title('Buyer Category')
plt.show
x_data = df['Category']
y_data = df['Size']

import numpy as np

fulfillment_counts = df['Fulfilment'].value_counts()


plt.figure(figsize=(6,6))
plt.pie(fulfillment_counts, labels=fulfillment_counts.index, autopct='%1.1f%%', colors=['navy', 'lightsteelblue'], wedgeprops=dict(width=0.4))
plt.title("Orders Fulfilled by Merchant vs Amazon")
plt.show()

import pandas as pd
import matplotlib.pyplot as plt


df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

monthly_avg = df.groupby(df['Date'].dt.to_period("M"))['Amount'].mean()
plt.figure(figsize=(8,5))
plt.plot(monthly_avg.index.astype(str), monthly_avg.values, marker='o', linestyle='-', color='teal')


plt.xlabel("Month")
plt.ylabel("Average Order Amount (INR)")
plt.title("Average Monthly Order Amount")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

plt.scatter(x_data,y_data)
plt.xlabel('Category')
plt.ylabel('Size')
plt.title('Available Size')
plt.show(block=True)

top10_state = df['ship-state'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.countplot(data=df[df['ship-state'].isin(top10_state.index)], 
              x='ship-state', 
              order=top10_state.index,  # Ensure correct order
              palette=sns.color_palette("tab10", 10))  # Use 10 distinct colors

plt.xlabel('State')
plt.ylabel('Orders Count')
plt.title('Distribution Across State')
plt.xticks(rotation=90)

plt.show()
                 



plt.tight_layout()
plt.show()
 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sayali\AppData\Local\Temp\ipykernel_13540\3310436489.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='Size',data=df,hue=None,palette='viridis')
# C:\Users\sayali\AppData\Local\Temp\ipykernel_13540\3310436489.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df[df['ship-state'].isin(top10_state.index)],

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html

# Load dataset
df = pd.read_csv(r'C:\Users\sayali\Documents\Amazon_sales_report2.csv')
df.dropna(inplace=True)
df.rename(columns=lambda x: x.strip(), inplace=True)
df['Date'] = pd.to_datetime(df['Date'])

# Ensure 'Courier Status' and 'ship-state' are cleaned
df['Courier Status'] = df['Courier Status'].str.strip()
df['ship-state'] = df['ship-state'].str.strip()

# Define color map for Courier Status
color_map = {
    'On the Way': '#FF5733',
    'Shipped': '#335BFF',
    'Unshipped': '#33FF57'
}

# Aggregate data for Shipping Status Chart
df_shipping_status = df.groupby("Courier Status", as_index=False)["Amount"].sum()

# Filter for Fulfilment type
df_filtered = df[df['Fulfilment'].isin(['Amazon', 'Merchant'])]

# Get Top 10 States for distribution (Sorted in descending order)
top_states = df['ship-state'].value_counts().nlargest(10).index
df_top_states = df[df['ship-state'].isin(top_states)].groupby('ship-state', as_index=False)['Amount'].sum()
df_top_states = df_top_states.sort_values(by='Amount', ascending=False)  # ✅ Sorted Highest to Lowest

# Initialize Dash app
app = Dash(__name__)

# Layout
app.layout = html.Div([
    html.H1("Amazon Sales Dashboard", style={'textAlign': 'center'}),
    
    # Summary Cards
    html.Div([
        html.Div([html.H3("Total Orders"), html.P(df.shape[0])], className='card'),
        html.Div([html.H3("Total Revenue"), html.P(f"${df['Amount'].sum():,.2f}")], className='card'),
        html.Div([html.H3("Unique Products"), html.P(df['Category'].nunique())], className='card'),
    ], style={'display': 'flex', 'justify-content': 'space-around'}),
    
    # Charts in a 2-column grid
    html.Div([
        html.Div(dcc.Graph(
            figure=px.histogram(df, x='Size', title='Count of Products By Sizes', color_discrete_sequence=['blue'])
        ), style={'width': '48%', 'display': 'inline-block'}),
        
        html.Div(dcc.Graph(
            figure=px.bar(df_shipping_status, x="Courier Status", y="Amount", 
                          title="Shipping Status Chart",
                          color="Courier Status", 
                          color_discrete_map=color_map)
        ), style={'width': '48%', 'display': 'inline-block'})
    ]),
    
    html.Div([
        html.Div(dcc.Graph(
            figure=px.histogram(df, x='Category', title='Product Sales By Category Histogram Chart', 
                                color_discrete_sequence=['yellow'])
        ), style={'width': '48%', 'display': 'inline-block'}),
        
        html.Div(dcc.Graph(
            figure=px.pie(df, names='B2B', title='Buyer Category Pie Chart', hole=0.3)
        ), style={'width': '48%', 'display': 'inline-block'})
    ]),
    
    html.Div([
        html.Div(dcc.Graph(
            figure=px.pie(df_filtered, names='Fulfilment', 
                          title='Order Fulfilled By Merchant vs Amazon Donut Chart', hole=0.5)
        ), style={'width': '48%', 'display': 'inline-block'}),
        
        html.Div(dcc.Graph(
            figure=px.scatter(df, x='Category', y='Size', title='Available Size Scatter Chart')
        ), style={'width': '48%', 'display': 'inline-block'})
    ]),
    
    html.Div([
        html.Div(dcc.Graph(
            figure=px.line(df.resample('M', on='Date').sum().reset_index(), x='Date', y='Amount', 
                           title='Average Monthly Order Amount Line Chart')
        ), style={'width': '48%', 'display': 'inline-block'}),
        
        html.Div(dcc.Graph(
            figure=px.bar(df_top_states, x='ship-state', y='Amount', title='Top 10 States - Distribution Chart',
                          color='ship-state', color_discrete_sequence=px.colors.qualitative.Pastel)
        ), style={'width': '48%', 'display': 'inline-block'})
    ])
])

# Run app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
# C:\Users\sayali\AppData\Local\Temp\ipykernel_11068\2524944594.py:9: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\sayali\AppData\Local\Temp\ipykernel_11068\2524944594.py:85: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
